# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time
import numpy as np
import os
import pandas as pd
pd.options.display.max_columns = 100
pd.options.display.max_rows = 130

# %%
from settings_shorts import (
    load_data_settings, audio_settings, load_video_configs
)
from utils_shorts import (
    load_category_data, load_examples_data, generate_and_zip_audio_files, stitch_audios
    , draw_vocab_list_whole_image, create_directories, create_video_with_highlights, create_video_without_highlights
)

# %% [markdown]
# # Create one video

# %%
df_categories = load_category_data()
df_examples = load_examples_data()
video_configs = load_video_configs()

# %%
start_time = time.time()
cat_start_stop_idx = (7, 20)
df_categories_use = df_categories[
    (df_categories['id'] >= cat_start_stop_idx[0]) &
    (df_categories['id'] <= cat_start_stop_idx[1])
]

for i_catrow, catrow in df_categories_use.iterrows():
    chosen_category = catrow['chinese']
    print(f'!!!!!!! {i_catrow} START: {chosen_category}: {(time.time() - start_time):.2f} !!!!!!!')
    data_settings = load_data_settings(df_categories, chosen_category)
    create_directories(data_settings)
    df_filt = df_examples[df_examples['category'] == data_settings['category']].reset_index(drop=True)
    example_words = df_filt['chinese'].values
    # generate_and_zip_audio_files(audio_settings['voice_name_zh'], chosen_category, example_words)
    df_durations = stitch_audios(audio_settings, data_settings, example_words)
    no_hl_img_file_path = draw_vocab_list_whole_image(video_configs, df_categories, data_settings, df_filt)
    create_video_without_highlights(data_settings, video_configs, no_hl_img_file_path)
    create_video_with_highlights(df_durations, audio_settings, data_settings, video_configs)
# Out:
# !!!!!!! 6 START: 坚果: 0.01 !!!!!!!
# Audio duration: 35.5s
# MoviePy - Building video output/anomia_shorts/坚果/坚果_no_highlights.mp4.
# MoviePy - Writing audio in 坚果_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/坚果/坚果_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/坚果/坚果_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/坚果/坚果.mp4.
# MoviePy - Writing audio in 坚果TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/坚果/坚果.mp4
# frame_index: 100%|█████████▉| 851/854 [00:18<00:00, 52.16it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/坚果/坚果_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 853 (out of a total 853 frames), at time 35.54/35.58 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/坚果/坚果.mp4
# !!!!!!! 7 START: 豆类: 36.17 !!!!!!!
# Audio duration: 34.0s
# MoviePy - Building video output/anomia_shorts/豆类/豆类_no_highlights.mp4.
# MoviePy - Writing audio in 豆类_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/豆类/豆类_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/豆类/豆类_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/豆类/豆类.mp4.
# MoviePy - Writing audio in 豆类TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/豆类/豆类.mp4
# frame_index: 100%|█████████▉| 818/819 [00:17<00:00, 42.44it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/豆类/豆类_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 817 (out of a total 818 frames), at time 34.04/34.09 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/豆类/豆类_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 818 (out of a total 818 frames), at time 34.08/34.09 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/豆类/豆类.mp4
# !!!!!!! 8 START: 家具: 70.10 !!!!!!!
# Audio duration: 33.7s
# MoviePy - Building video output/anomia_shorts/家具/家具_no_highlights.mp4.
# MoviePy - Writing audio in 家具_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/家具/家具_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/家具/家具_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/家具/家具.mp4.
# MoviePy - Writing audio in 家具TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/家具/家具.mp4
# frame_index:  99%|█████████▉| 806/811 [00:17<00:00, 51.93it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/家具/家具_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 810 (out of a total 810 frames), at time 33.75/33.78 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/家具/家具.mp4
# !!!!!!! 9 START: 树: 105.39 !!!!!!!
# Audio duration: 35.0s
# MoviePy - Building video output/anomia_shorts/树/树_no_highlights.mp4.
# MoviePy - Writing audio in 树_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/树/树_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/树/树_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/树/树.mp4.
# MoviePy - Writing audio in 树TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/树/树.mp4
# frame_index: 100%|█████████▉| 839/841 [00:19<00:00, 46.91it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/树/树_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 840 (out of a total 840 frames), at time 35.00/35.03 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/树/树.mp4
# !!!!!!! 10 START: 学科: 143.74 !!!!!!!
# Audio duration: 35.9s
# MoviePy - Building video output/anomia_shorts/学科/学科_no_highlights.mp4.
# MoviePy - Writing audio in 学科_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/学科/学科_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/学科/学科_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/学科/学科.mp4.
# MoviePy - Writing audio in 学科TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/学科/学科.mp4
# frame_index: 100%|█████████▉| 862/865 [00:17<00:00, 49.73it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/学科/学科_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 864 (out of a total 864 frames), at time 36.00/36.02 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/学科/学科.mp4
# !!!!!!! 11 START: 电子游戏: 178.76 !!!!!!!
# Audio duration: 42.0s
# MoviePy - Building video output/anomia_shorts/电子游戏/电子游戏_no_highlights.mp4.
# MoviePy - Writing audio in 电子游戏_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/电子游戏/电子游戏_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/电子游戏/电子游戏_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/电子游戏/电子游戏.mp4.
# MoviePy - Writing audio in 电子游戏TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/电子游戏/电子游戏.mp4
# frame_index: 100%|█████████▉| 1007/1010 [00:22<00:00, 45.17it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/电子游戏/电子游戏_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 1009 (out of a total 1009 frames), at time 42.04/42.08 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/电子游戏/电子游戏.mp4
# !!!!!!! 12 START: 标点符号: 222.98 !!!!!!!
# Audio duration: 34.7s
# MoviePy - Building video output/anomia_shorts/标点符号/标点符号_no_highlights.mp4.
# MoviePy - Writing audio in 标点符号_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/标点符号/标点符号_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/标点符号/标点符号_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/标点符号/标点符号.mp4.
# MoviePy - Writing audio in 标点符号TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/标点符号/标点符号.mp4
# frame_index: 100%|█████████▉| 833/834 [00:16<00:00, 48.70it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/标点符号/标点符号_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 832 (out of a total 833 frames), at time 34.67/34.72 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/标点符号/标点符号_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 833 (out of a total 833 frames), at time 34.71/34.72 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/标点符号/标点符号.mp4
# !!!!!!! 13 START: 颜色: 257.07 !!!!!!!
# Audio duration: 34.5s
# MoviePy - Building video output/anomia_shorts/颜色/颜色_no_highlights.mp4.
# MoviePy - Writing audio in 颜色_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/颜色/颜色_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/颜色/颜色_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/颜色/颜色.mp4.
# MoviePy - Writing audio in 颜色TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/颜色/颜色.mp4
# frame_index: 100%|██████████| 830/830 [00:16<00:00, 49.51it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/颜色/颜色_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 829 (out of a total 829 frames), at time 34.54/34.56 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/颜色/颜色.mp4
# !!!!!!! 14 START: 昆虫: 290.95 !!!!!!!
# Audio duration: 33.5s
# MoviePy - Building video output/anomia_shorts/昆虫/昆虫_no_highlights.mp4.
# MoviePy - Writing audio in 昆虫_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/昆虫/昆虫_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/昆虫/昆虫_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/昆虫/昆虫.mp4.
# MoviePy - Writing audio in 昆虫TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/昆虫/昆虫.mp4
# frame_index: 100%|██████████| 807/807 [00:16<00:00, 51.77it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/昆虫/昆虫_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 806 (out of a total 806 frames), at time 33.58/33.62 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/昆虫/昆虫.mp4
# !!!!!!! 15 START: 肉类食品: 323.62 !!!!!!!
# Audio duration: 34.5s
# MoviePy - Building video output/anomia_shorts/肉类食品/肉类食品_no_highlights.mp4.
# MoviePy - Writing audio in 肉类食品_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/肉类食品/肉类食品_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/肉类食品/肉类食品_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/肉类食品/肉类食品.mp4.
# MoviePy - Writing audio in 肉类食品TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/肉类食品/肉类食品.mp4
# frame_index: 100%|█████████▉| 826/830 [00:16<00:00, 52.99it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/肉类食品/肉类食品_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 829 (out of a total 829 frames), at time 34.54/34.56 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/肉类食品/肉类食品.mp4
# !!!!!!! 16 START: 地标: 355.94 !!!!!!!
# Audio duration: 40.1s
# MoviePy - Building video output/anomia_shorts/地标/地标_no_highlights.mp4.
# MoviePy - Writing audio in 地标_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/地标/地标_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/地标/地标_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/地标/地标.mp4.
# MoviePy - Writing audio in 地标TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/地标/地标.mp4
# frame_index: 100%|█████████▉| 962/964 [00:19<00:00, 47.82it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/地标/地标_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 963 (out of a total 963 frames), at time 40.12/40.15 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/地标/地标.mp4
# !!!!!!! 17 START: 篮球队: 393.94 !!!!!!!
# Audio duration: 46.7s
# MoviePy - Building video output/anomia_shorts/篮球队/篮球队_no_highlights.mp4.
# MoviePy - Writing audio in 篮球队_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/篮球队/篮球队_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/篮球队/篮球队_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/篮球队/篮球队.mp4.
# MoviePy - Writing audio in 篮球队TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/篮球队/篮球队.mp4
# frame_index: 100%|█████████▉| 1119/1123 [00:22<00:00, 48.41it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/篮球队/篮球队_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 1122 (out of a total 1122 frames), at time 46.75/46.76 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/篮球队/篮球队.mp4
# !!!!!!! 18 START: 汽车零件: 440.28 !!!!!!!
# Audio duration: 36.3s
# MoviePy - Building video output/anomia_shorts/汽车零件/汽车零件_no_highlights.mp4.
# MoviePy - Writing audio in 汽车零件_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/汽车零件/汽车零件_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/汽车零件/汽车零件_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/汽车零件/汽车零件.mp4.
# MoviePy - Writing audio in 汽车零件TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/汽车零件/汽车零件.mp4
# frame_index:  99%|█████████▉| 867/872 [00:16<00:00, 45.52it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/汽车零件/汽车零件_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 871 (out of a total 871 frames), at time 36.29/36.31 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/汽车零件/汽车零件.mp4
# !!!!!!! 19 START: 医疗器材: 474.18 !!!!!!!
# Audio duration: 38.0s
# MoviePy - Building video output/anomia_shorts/医疗器材/医疗器材_no_highlights.mp4.
# MoviePy - Writing audio in 医疗器材_no_highlightsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/医疗器材/医疗器材_no_highlights.mp4
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/医疗器材/医疗器材_no_highlights.mp4
# MoviePy - Building video output/anomia_shorts/医疗器材/医疗器材.mp4.
# MoviePy - Writing audio in 医疗器材TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video output/anomia_shorts/医疗器材/医疗器材.mp4
# frame_index: 100%|█████████▉| 913/914 [00:17<00:00, 52.87it/s, now=None]/Users/scott/Library/Caches/pypoetry/virtualenvs/my-mandarin-database-XyoBA6Fv-py3.13/lib/python3.13/site-packages/moviepy/video/io/ffmpeg_reader.py:190: UserWarning: In file output/anomia_shorts/医疗器材/医疗器材_no_highlights.mp4, 2764800 bytes wanted but 0 bytes read at frame index 913 (out of a total 913 frames), at time 38.04/38.06 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready output/anomia_shorts/医疗器材/医疗器材.mp4
